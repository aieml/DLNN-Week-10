# %%
import gym
#Gym is a toolkit for developing and comparing reinforcement learning algorithms. 
#It supports teaching agents everything from walking to playing games like Pong or Pinball.

env=gym.make("MountainCar-v0")
#setting the environment to Cart Pole
env.reset()
#resetting the environment
while(True):
    
    new_state=env.step(1)
    #performing 0 action to the environment
    print(new_state)
    env.render()
# Out:
# (array([-0.41357502, -0.00081606]), -1.0, False, {})
# (array([-0.41520136, -0.00162634]), -1.0, False, {})
# (array([-0.41762643, -0.00242507]), -1.0, False, {})
# (array([-0.42083296, -0.00320654]), -1.0, False, {})
# (array([-0.4247981 , -0.00396513]), -1.0, False, {})
# (array([-0.42949343, -0.00469533]), -1.0, False, {})
# (array([-0.43488521, -0.00539179]), -1.0, False, {})
# (array([-0.44093453, -0.00604931]), -1.0, False, {})
# (array([-0.44759748, -0.00666296]), -1.0, False, {})
# (array([-0.45482552, -0.00722804]), -1.0, False, {})
# (array([-0.46256571, -0.00774019]), -1.0, False, {})
# (array([-0.47076109, -0.00819538]), -1.0, False, {})
# (array([-0.4793511 , -0.00859001]), -1.0, False, {})
# (array([-0.48827199, -0.00892089]), -1.0, False, {})
# (array([-0.49745734, -0.00918535]), -1.0, False, {})
# (array([-0.50683855, -0.00938121]), -1.0, False, {})
# (array([-0.5163454 , -0.00950686]), -1.0, False, {})
# (array([-0.52590666, -0.00956125]), -1.0, False, {})
# ...
